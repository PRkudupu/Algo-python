# %% [markdown]
# Given a string S and a string T, find the minimum window in S which will contain all the characters in T in complexity O(n).
#
# Example:
# <code>
# Input: S = "ADOBECODEBANC", T = "ABC"
# Output: "BANC"
# Note:
# </code>
#
# If there is no such window in S that covers all characters in T, return the empty string "".
# If there is such window, you are guaranteed that there will always be only one unique minimum window in S.

# %% [markdown]
# ![title](image/min_window_substring_1.jpg)

# %%
# Solution with comments
from collections import Counter

def minWindow(ls, t):
    if not t or not ls:
        return ""
    dic = Counter(t) 
    required = len(dic) 
    l, r = 0, 0 
    formed = 0  
    w_counts = {}    
    ans = float("inf"), None, None     
    while r < len(ls):
        ch = ls[r]
        w_counts[ch] = w_counts.get(ch, 0) + 1
        if ch in dic and w_counts[ch] == dic[ch]:
            formed += 1
        while l <= r and formed == required:
            ch = ls[l]
            # Save the smallest window until now.
            if r - l + 1 < ans[0]:
                ans = (r - l + 1, l, r)
            # Save the smallest window until now.
            w_counts[ch] -= 1
            if ch in dic and w_counts[ch] < dic[ch]:
                formed -= 1
            l += 1   
        r += 1 
    return "" if ans[0] == float("inf") else ls[ans[1] : ans[2] + 1]
print(minWindow('abfgdefgabgd','abd'))
# Out:
# abgd

# %%
# Solution with comments
from collections import Counter

def minWindow(s, t):
    if not t or not s:
        return ""
    # Dictionary which keeps a count of all the unique characters in t.
    dic = Counter(t) 
    # Number of unique characters in t, which need to be present in the desired window.
    required = len(dic) 
    # left and right pointer
    l, r = 0, 0 
     # formed is used to keep track of how many unique characters in t are present in the current   window in its desired frequency.
    # e.g. if t is "AABC" then the window must have two A's, one B and one C. Thus formed would be = 3 when all these conditions are met.
    formed = 0  
    # Dictionary which keeps a count of all the unique characters in the current window.
    w_counts = {}    
    # ans tuple of the form (window length, left, right)
    ans = float("inf"), None, None     
    while r < len(s):
        # Add one character from the right to the window
        ch = s[r]
        # If the frequency of the current character added equals to the desired count in t then increment the formed count by 1.
        w_counts[ch] = w_counts.get(ch, 0) + 1
        if ch in dic and w_counts[ch] == dic[ch]:
            formed += 1
        # Try and contract the window till the point where it ceases to be 'desirable'.
        while l <= r and formed == required:
            ch = s[l]
            # Save the smallest window until now.
            if r - l + 1 < ans[0]:
                ans = (r - l + 1, l, r)
            # Save the smallest window until now.
            w_counts[ch] -= 1
            if ch in dic and w_counts[ch] < dic[ch]:
                formed -= 1
            # Save the smallest window until now.
            l += 1   
         # Keep expanding the window once we are done contracting.
        r += 1 
    return "" if ans[0] == float("inf") else s[ans[1] : ans[2] + 1]
print(minWindow('abfgdefgabgd','abd'))
# Out:
# abgd

# %%
# solution with print
from collections import Counter

def minWindow(s, t):
    if not t or not s:
        return ""
    dic = Counter(t) 
    required = len(dic) 
    l, r = 0, 0 
    formed = 0  
    
    w_counts = {}
    ans = float("inf"), None, None     
    while r < len(s):
        ch = s[r]
        print('\nch',ch)
        print('required',required)
        print('ans',ans)
        print('w_counts.get(ch, 0)',w_counts.get(ch, 0)+1)
        w_counts[ch] = w_counts.get(ch, 0) + 1
        print('w_counts',w_counts)
        print('dic',dic)
        # If the frequency of the current character added equals to the desired count in t then increment the formed count by 1.
        if ch in dic and w_counts[ch] == dic[ch]:
            formed += 1
        print('formed',formed)
        print('l before',l)
        print('r before',r)
        while l <= r and formed == required:
            print('r',r)
            print('l',l)
            print('INSIDE WHILE')
            ch = s[l]
            if r - l + 1 < ans[0]:
                ans = (r - l + 1, l, r)
            w_counts[ch] -= 1
            if ch in dic and w_counts[ch] < dic[ch]:
                formed -= 1
            l += 1    
        r += 1 
        print('ans',ans)
    return "" if ans[0] == float("inf") else s[ans[1] : ans[2] + 1]
print(minWindow('abfgdefgabd','abd'))
# Out:
# ch a
# required 3
# ans (inf, None, None)
# w_counts.get(ch, 0) 1
# w_counts {'a': 1}
# dic Counter({'a': 1, 'b': 1, 'd': 1})
# formed 1
# l before 0
# r before 0
# ans (inf, None, None)
#
# ch b
# required 3
# ans (inf, None, None)
# w_counts.get(ch, 0) 1
# w_counts {'a': 1, 'b': 1}
# dic Counter({'a': 1, 'b': 1, 'd': 1})
# formed 2
# l before 0
# r before 1
# ans (inf, None, None)
#
# ch f
# required 3
# ans (inf, None, None)
# w_counts.get(ch, 0) 1
# w_counts {'a': 1, 'b': 1, 'f': 1}
# dic Counter({'a': 1, 'b': 1, 'd': 1})
# formed 2
# l before 0
# r before 2
# ans (inf, None, None)
#
# ch g
# required 3
# ans (inf, None, None)
# w_counts.get(ch, 0) 1
# w_counts {'a': 1, 'b': 1, 'f': 1, 'g': 1}
# dic Counter({'a': 1, 'b': 1, 'd': 1})
# formed 2
# l before 0
# r before 3
# ans (inf, None, None)
#
# ch d
# required 3
# ans (inf, None, None)
# w_counts.get(ch, 0) 1
# w_counts {'a': 1, 'b': 1, 'f': 1, 'g': 1, 'd': 1}
# dic Counter({'a': 1, 'b': 1, 'd': 1})
# formed 3
# l before 0
# ...
